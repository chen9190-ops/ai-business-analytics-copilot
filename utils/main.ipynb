# %%
import pandas as pd

from data_cleaning import *
from analysis import *
from llm_analysis import *
from ai_agent import *


df = pd.read_csv("dirty_superstore.csv",encoding="latin1")

# %%
# ==========================================
# Detect Dataset Schema
# ==========================================

schema = detect_column_types(df)

print("Detected Schema:")
print(schema)

# ==========================================
# Data Cleaning
# ==========================================

print("\nRunning data cleaning...")

df = clean_data(df)

print("Data cleaning completed.")


# ==========================================
# AI Business Agent
# ==========================================

print("\nAI Business Analytics Copilot")

question = input(
    "\nAsk a business question: "
)


# ==========================================
# AI Agent Answer
# ==========================================

answer = answer_business_question(
    question,
    df
)


# ==========================================
# Final Output
# ==========================================

print("\n")
print("AI Business Insight:")
print(answer)
# Out:
# Detected Schema:
# {'numeric': ['Postal Code', 'Sales', 'Quantity', 'Discount', 'Profit'], 'categorical': ['Ship Mode', 'Customer Name', 'Segment', 'Country', 'City', 'State', 'Region', 'Category', 'Sub-Category', 'Product Name'], 'datetime': ['Order Date', 'Ship Date'], 'id': ['Row ID', 'Order ID', 'Customer ID', 'Product ID']}
#
# Running data cleaning...
# Checking missing values...
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    5
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            8
# Quantity         0
# Discount         0
# Profit           7
# dtype: int64
# Detecting outliers...
# {'Row ID': 0, 'Postal Code': 0, 'Sales': 1173, 'Quantity': 170, 'Discount': 856, 'Profit': 1880}
# State cleaning completed.
# ...
